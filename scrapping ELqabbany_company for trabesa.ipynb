# %%
import requests
from bs4 import BeautifulSoup
l_link = []
l_name = []
l_befor = []
l_after= []
url="https://www.kabbanifurniture.com/collections/%D8%AA%D8%B1%D8%A7%D8%A8%D9%8A%D8%B2%D8%A7%D8%AA-%D9%88%D8%B3%D8%B7-g"
page = requests.get(url).content
soup = BeautifulSoup(page, 'html.parser')
#print(soup.prettify())
##links of all bedrooms
links = soup.find_all('div',{'class':'grid-view_image'})
for link in links:
    l = link.a.attrs['href']
    l = "https://www.kabbanifurniture.com" + l
    l_link.append(l)
#names of all bedrooms
names = soup.find_all('div',{'class':'details'})
for name in names:
    n = name.a.text
    l_name.append(n)
#price of all bedrooms befor discount
b_prices = soup.find_all('div', {'class': 'grid-view-item__meta'})
for b_price in b_prices:
    b = b_price.s.text
    l_befor.append(b)
#price after all bedrooms discount
a_prices = soup.find_all('span', {'class': 'product-price__price product-price__sale'})
for a_price in a_prices:
    a = a_price.text
    l_after.append(a)
#visualize data that were scraped
for i in range(len(l_link)):
    print("the name of tables : ",l_name[i])
    print("     ")
    print("the link of tables : ",l_link[i])
    print("     ")
    print("the price before discount of tables : ",l_befor[i])
    print("     ")
    print("the price after the discount of tables : ",l_after[i])
    print("     ")
    print("***************************************************")
    print("     ")
# Out:
# the name of tables :  ترابيزة وسط G1
#
# the link of tables :  https://www.kabbanifurniture.com/collections/%D8%AA%D8%B1%D8%A7%D8%A8%D9%8A%D8%B2%D8%A7%D8%AA-%D9%88%D8%B3%D8%B7-g/products/%D8%AA%D8%B1%D8%A7%D8%A8%D9%8A%D8%B2%D8%A9-b1
#
# the price before discount of tables :  LE 3,075
#
# the price after the discount of tables :  LE 1,690
#
# ***************************************************
#
# the name of tables :  ترابيزة وسط G1
#
# the link of tables :  https://www.kabbanifurniture.com/collections/%D8%AA%D8%B1%D8%A7%D8%A8%D9%8A%D8%B2%D8%A7%D8%AA-%D9%88%D8%B3%D8%B7-g/products/%D8%AA%D8%B1%D8%A7%D8%A8%D9%8A%D8%B2%D8%A9-%D9%88%D8%B3%D8%B7-b1
#
# the price before discount of tables :  LE 3,075
#
# the price after the discount of tables :  LE 1,690
#
# ***************************************************
#
# the name of tables :  KT-326 ترابيزة وسط
#
# the link of tables :  https://www.kabbanifurniture.com/collections/%D8%AA%D8%B1%D8%A7%D8%A8%D9%8A%D8%B2%D8%A7%D8%AA-%D9%88%D8%B3%D8%B7-g/products/kt-326-%D8%AA%D8%B1%D8%A7%D8%A8%D9%8A%D8%B2%D8%A9-%D9%88%D8%B3%D8%B7
#
# the price before discount of tables :  LE 5,910
#
# the price after the discount of tables :  LE 3,250
#
# ***************************************************
#
# the name of tables :  ترابيزة وسط KT-305
#
# the link of tables :  https://www.kabbanifurniture.com/collections/%D8%AA%D8%B1%D8%A7%D8%A8%D9%8A%D8%B2%D8%A7%D8%AA-%D9%88%D8%B3%D8%B7-g/products/d8-aa-d8-b1-d8-a7-d8-a8-d9-8a-d8-b2-d8-a9-d9-88-d8-b3-d8-b7-kt-305
#
# the price before discount of tables :  LE 5,990
#
# the price after the discount of tables :  LE 3,290
#
# ***************************************************
#
# the name of tables :  ترابيزة وسط G2
#
# the link of tables :  https://www.kabbanifurniture.com/collections/%D8%AA%D8%B1%D8%A7%D8%A8%D9%8A%D8%B2%D8%A7%D8%AA-%D9%88%D8%B3%D8%B7-g/products/%D8%AA%D8%B1%D8%A7%D8%A8%D9%8A%D8%B2%D8%A9-%D9%88%D8%B3%D8%B7-g2
#
# the price before discount of tables :  LE 5,865
#
# the price after the discount of tables :  LE 4,690
#
# ***************************************************
#
# the name of tables :  KT-337 ترابيزة وسط
#
# the link of tables :  https://www.kabbanifurniture.com/collections/%D8%AA%D8%B1%D8%A7%D8%A8%D9%8A%D8%B2%D8%A7%D8%AA-%D9%88%D8%B3%D8%B7-g/products/%D8%AA%D8%B1%D8%A7%D8%A8%D9%8A%D8%B2%D8%A9-%D9%88%D8%B3%D8%B7-kt-320
#
# the price before discount of tables :  LE 7,870
#
# the price after the discount of tables :  LE 5,490
#
# ***************************************************
#
# the name of tables :  ترابيزة وسط KT-323
#
# the link of tables :  https://www.kabbanifurniture.com/collections/%D8%AA%D8%B1%D8%A7%D8%A8%D9%8A%D8%B2%D8%A7%D8%AA-%D9%88%D8%B3%D8%B7-g/products/%D8%AA%D8%B1%D8%A7%D8%A8%D9%8A%D8%B2%D8%A9-%D9%88%D8%B3%D8%B7-kt-324
#
# the price before discount of tables :  LE 7,850
#
# the price after the discount of tables :  LE 5,490
#
# ***************************************************
#
# the name of tables :  KT-336 ترابيزة وسط
#
# the link of tables :  https://www.kabbanifurniture.com/collections/%D8%AA%D8%B1%D8%A7%D8%A8%D9%8A%D8%B2%D8%A7%D8%AA-%D9%88%D8%B3%D8%B7-g/products/kt-320-%D8%AA%D8%B1%D8%A7%D8%A8%D9%8A%D8%B2%D8%A9-%D9%88%D8%B3%D8%B7
#
# the price before discount of tables :  LE 7,870
#
# the price after the discount of tables :  LE 5,490
#
# ***************************************************
#
# the name of tables :  ترابيزة وسط KT-318
#
# the link of tables :  https://www.kabbanifurniture.com/collections/%D8%AA%D8%B1%D8%A7%D8%A8%D9%8A%D8%B2%D8%A7%D8%AA-%D9%88%D8%B3%D8%B7-g/products/d8-aa-d8-b1-d8-a7-d8-a8-d9-8a-d8-b2-d8-a9-d9-88-d8-b3-d8-b7-kt-318
#
# the price before discount of tables :  LE 7,490
#
# the price after the discount of tables :  LE 5,990
#
# ***************************************************
#
# the name of tables :  ترابيزة وسط KT-304
#
# the link of tables :  https://www.kabbanifurniture.com/collections/%D8%AA%D8%B1%D8%A7%D8%A8%D9%8A%D8%B2%D8%A7%D8%AA-%D9%88%D8%B3%D8%B7-g/products/d8-aa-d8-b1-d8-a7-d8-a8-d9-8a-d8-b2-d8-a9-d9-88-d8-b3-d8-b7-kt-304
#
# the price before discount of tables :  LE 7,490
#
# the price after the discount of tables :  LE 5,990
#
# ***************************************************
#
# the name of tables :  KT-334 ترابيزة وسط
#
# the link of tables :  https://www.kabbanifurniture.com/collections/%D8%AA%D8%B1%D8%A7%D8%A8%D9%8A%D8%B2%D8%A7%D8%AA-%D9%88%D8%B3%D8%B7-g/products/kt-329-%D8%AA%D8%B1%D8%A7%D8%A8%D9%8A%D8%B2%D8%A9-%D9%88%D8%B3%D8%B7-1
#
# the price before discount of tables :  LE 7,490
#
# the price after the discount of tables :  LE 5,990
#
# ***************************************************
#
# the name of tables :  ترابيزة وسط KT-323
#
# the link of tables :  https://www.kabbanifurniture.com/collections/%D8%AA%D8%B1%D8%A7%D8%A8%D9%8A%D8%B2%D8%A7%D8%AA-%D9%88%D8%B3%D8%B7-g/products/%D8%AA%D8%B1%D8%A7%D8%A8%D9%8A%D8%B2%D8%A9-%D9%88%D8%B3%D8%B7-kt-323
#
# the price before discount of tables :  LE 9,280
#
# the price after the discount of tables :  LE 6,490
#
# ***************************************************
#
# the name of tables :  Emerald ترابيزة وسط
#
# the link of tables :  https://www.kabbanifurniture.com/collections/%D8%AA%D8%B1%D8%A7%D8%A8%D9%8A%D8%B2%D8%A7%D8%AA-%D9%88%D8%B3%D8%B7-g/products/emerald-%D8%AA%D8%B1%D8%A7%D8%A8%D9%8A%D8%B2%D8%A9-%D9%88%D8%B3%D8%B7
#
# the price before discount of tables :  LE 8,740
#
# the price after the discount of tables :  LE 6,990
#
# ***************************************************
#
# the name of tables :  ترابيزة وسط KT-338
#
# the link of tables :  https://www.kabbanifurniture.com/collections/%D8%AA%D8%B1%D8%A7%D8%A8%D9%8A%D8%B2%D8%A7%D8%AA-%D9%88%D8%B3%D8%B7-g/products/%D8%AA%D8%B1%D8%A7%D8%A8%D9%8A%D8%B2%D8%A9-%D9%88%D8%B3%D8%B7-kt-338
#
# the price before discount of tables :  LE 9,370
#
# the price after the discount of tables :  LE 7,490
#
# ***************************************************
#
# the name of tables :  ترابيزة وسط KT-338
#
# the link of tables :  https://www.kabbanifurniture.com/collections/%D8%AA%D8%B1%D8%A7%D8%A8%D9%8A%D8%B2%D8%A7%D8%AA-%D9%88%D8%B3%D8%B7-g/products/%D8%AA%D8%B1%D8%A7%D8%A8%D9%8A%D8%B2%D8%A9-%D9%88%D8%B3%D8%B7-kt-339
#
# the price before discount of tables :  LE 9,370
#
# the price after the discount of tables :  LE 7,490
#
# ***************************************************
#
# the name of tables :  ترابيزة وسط KT-338
#
# the link of tables :  https://www.kabbanifurniture.com/collections/%D8%AA%D8%B1%D8%A7%D8%A8%D9%8A%D8%B2%D8%A7%D8%AA-%D9%88%D8%B3%D8%B7-g/products/%D8%AA%D8%B1%D8%A7%D8%A8%D9%8A%D8%B2%D8%A9-%D9%88%D8%B3%D8%B7-kt-340
#
# the price before discount of tables :  LE 9,370
#
# the price after the discount of tables :  LE 7,490
#
# ***************************************************
#
# the name of tables :  عرض افرش بيتك
#
# the link of tables :  https://www.kabbanifurniture.com/collections/%D8%AA%D8%B1%D8%A7%D8%A8%D9%8A%D8%B2%D8%A7%D8%AA-%D9%88%D8%B3%D8%B7-g/products/%D8%B9%D8%B1%D8%B6-%D8%A7%D9%81%D8%B1%D8%B4-%D8%A8%D9%8A%D8%AA%D9%83
#
# the price before discount of tables :  LE 114,505
#
# the price after the discount of tables :  LE 64,990
#
# ***************************************************
#
# the name of tables :  غرفة نوم كارما
#
# the link of tables :  https://www.kabbanifurniture.com/collections/%D8%AA%D8%B1%D8%A7%D8%A8%D9%8A%D8%B2%D8%A7%D8%AA-%D9%88%D8%B3%D8%B7-g/products/%D8%BA%D8%B1%D9%81%D8%A9-%D9%86%D9%88%D9%85-%D9%83%D8%A7%D8%B1%D9%85%D8%A7
#
# the price before discount of tables :  LE 43,740
#
# the price after the discount of tables :  LE 34,990
#
# ***************************************************
#
# the name of tables :  أنتريه سويفت
#
# the link of tables :  https://www.kabbanifurniture.com/collections/%D8%AA%D8%B1%D8%A7%D8%A8%D9%8A%D8%B2%D8%A7%D8%AA-%D9%88%D8%B3%D8%B7-g/products/%D8%A3%D9%86%D8%AA%D8%B1%D9%8A%D8%A9-%D8%B3%D9%88%D9%8A%D9%81%D8%AA
#
# the price before discount of tables :  LE 28,080
#
# the price after the discount of tables :  LE 19,650
#
# ***************************************************
#
# the name of tables :  أرجوحة تيوب جاردن راتان
#
# the link of tables :  https://www.kabbanifurniture.com/collections/%D8%A3%D8%AB%D8%A7%D8%AB-%D8%A7%D9%84%D8%AD%D8%AF%D8%A7%D8%A6%D9%82-g/products/%D8%A3%D8%B1%D8%AC%D9%88%D8%AD%D8%A9-%D8%AA%D9%8A%D9%88%D8%A8-%D8%AC%D8%A7%D8%B1%D8%AF%D9%86-%D8%B1%D8%A7%D8%AA%D8%A7%D9%86
#
# the price before discount of tables :  LE 6,120
#
# the price after the discount of tables :  LE 3,950
#
# ***************************************************
#
# the name of tables :  ميني صن فلاور
#
# the link of tables :  https://www.kabbanifurniture.com/collections/%D8%A3%D8%AB%D8%A7%D8%AB-%D8%A7%D9%84%D8%AD%D8%AF%D8%A7%D8%A6%D9%82-g/products/%D9%85%D9%8A%D9%86%D9%8A-%D8%B5%D9%86-%D9%81%D9%84%D8%A7%D9%88%D8%B1
#
# the price before discount of tables :  LE 5,285
#
# the price after the discount of tables :  LE 3,970
#
# ***************************************************
#
# the name of tables :  أرجوحة نيو جاردن راتان
#
# the link of tables :  https://www.kabbanifurniture.com/collections/%D8%A3%D8%AB%D8%A7%D8%AB-%D8%A7%D9%84%D8%AD%D8%AF%D8%A7%D8%A6%D9%82-g/products/%D8%A3%D8%B1%D8%AC%D9%88%D8%AD%D8%A9-%D9%86%D9%8A%D9%88-%D8%AC%D8%A7%D8%B1%D8%AF%D9%86-%D8%B1%D8%A7%D8%AA%D8%A7%D9%86
#
# the price before discount of tables :  LE 6,440
#
# the price after the discount of tables :  LE 4,185
#
# ***************************************************
#
# the name of tables :  شيزلونج كاريبيان
#
# the link of tables :  https://www.kabbanifurniture.com/collections/%D8%A3%D8%AB%D8%A7%D8%AB-%D8%A7%D9%84%D8%AD%D8%AF%D8%A7%D8%A6%D9%82-g/products/%D8%B4%D8%A7%D8%B2%D9%84%D9%88%D9%86%D8%AC-%D9%83%D8%A7%D8%B1%D9%8A%D8%A8%D9%8A%D8%A7%D9%86
#
# the price before discount of tables :  LE 5,680
#
# the price after the discount of tables :  LE 4,260
#
# ***************************************************
#
# the name of tables :  طقم ميني
#
# the link of tables :  https://www.kabbanifurniture.com/collections/%D8%A3%D8%AB%D8%A7%D8%AB-%D8%A7%D9%84%D8%AD%D8%AF%D8%A7%D8%A6%D9%82-g/products/%D8%B7%D9%82%D9%85-%D9%85%D9%8A%D9%86%D9%8A
#
# the price before discount of tables :  LE 5,895
#
# the price after the discount of tables :  LE 4,700
#
# ***************************************************
